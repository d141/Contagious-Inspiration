# %%
import pandas as pd

ids = pd.read_csv('data_all_post_ids.csv')

# %%
ids.head()
# Out:
#   inspiring not inspiring
# 0    18ypya        5s6czm
# 1    8u3p2f        2q1xjz
# 2    194wmf        16ff5p
# 3    1h8ctp        18fto4
# 4    17pkxd        671m2n

# %%
submissions = pd.read_json('comments_submission_all.json')

# %%
submissions.head()
# Out:
#                                                             0    ...                                                110
# subreddit                                                  food  ...                                        GunsAreCool
# id                                                       14v5iw  ...                                             15qmm5
# comment_body  Made them for Christmas, with the cheese sauce...  ...  That was my post...and after getting slammed f...
# score_com                                                     1  ...                                                  2
# title               Deep fried hot dog stars with cheese sauce.  ...                       If this redditor snaps... 11
#
# [5 rows x 111 columns]

# %%
submissions = submissions.transpose()

# %%
submissions[submissions['id'] == '15q2g1']['comment_body'].all()
# Out:
# "Dj shadow is my favorite artist and a top-tier performer.  His live sets, be it his music or a set of tunes that have inspired and grooved him, are phenomenal.  This club's  decision  robbed at least one person in the crowd the joy of  not only shadow's music, but the music of obscure and long forgotten artists past.  This is a shame.\n\nJosh, feel free to come to nola anytime.  I have enjoyed your previous four visits, and will continue to bob my head at every show forthwith.......cheers\n"

# %%
len(submissions)
# Out:
# 111

# %%
inspiring=ids['inspiring']
not_inspiring=ids['not inspiring']

# %%
inspiring = pd.DataFrame(inspiring).assign(result = 1)
not_inspiring = pd.DataFrame(not_inspiring).assign(result = 0)

# %%
inspiring = inspiring.rename(columns = {'inspiring':'id'})
not_inspiring = not_inspiring.rename(columns = {'not inspiring':'id'})

# %%
df = inspiring.append(not_inspiring)

# %%
len(df)
# Out:
# 11590

# %%
df.head()
# Out:
#        id  result
# 0  18ypya       1
# 1  8u3p2f       1
# 2  194wmf       1
# 3  1h8ctp       1
# 4  17pkxd       1

# %%
pip install psaw
# Out:
# Collecting psaw
#   Downloading psaw-0.1.0-py3-none-any.whl (15 kB)
# Requirement already satisfied: Click in /usr/local/lib/python3.7/dist-packages (from psaw) (7.1.2)
# Requirement already satisfied: requests in /usr/local/lib/python3.7/dist-packages (from psaw) (2.23.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests->psaw) (2021.5.30)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests->psaw) (2.10)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests->psaw) (3.0.4)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests->psaw) (1.24.3)
# Installing collected packages: psaw
# Successfully installed psaw-0.1.0

# %%
pip install praw
# Out:
# Collecting praw
#   Downloading praw-7.4.0-py3-none-any.whl (167 kB)
#      |████████████████████████████████| 167 kB 5.2 MB/s
# Collecting update-checker>=0.18
#   Downloading update_checker-0.18.0-py3-none-any.whl (7.0 kB)
# Collecting prawcore<3,>=2.1
#   Downloading prawcore-2.3.0-py3-none-any.whl (16 kB)
# Collecting websocket-client>=0.54.0
#   Downloading websocket_client-1.2.1-py2.py3-none-any.whl (52 kB)
#      |████████████████████████████████| 52 kB 1.3 MB/s
# Requirement already satisfied: requests<3.0,>=2.6.0 in /usr/local/lib/python3.7/dist-packages (from prawcore<3,>=2.1->praw) (2.23.0)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests<3.0,>=2.6.0->prawcore<3,>=2.1->praw) (1.24.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests<3.0,>=2.6.0->prawcore<3,>=2.1->praw) (2021.5.30)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests<3.0,>=2.6.0->prawcore<3,>=2.1->praw) (2.10)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests<3.0,>=2.6.0->prawcore<3,>=2.1->praw) (3.0.4)
# Installing collected packages: websocket-client, update-checker, prawcore, praw
# Successfully installed praw-7.4.0 prawcore-2.3.0 update-checker-0.18.0 websocket-client-1.2.1

# %%
import praw

reddit = praw.Reddit(client_id='F77JkePeSXMBgL_u3m9CBQ',
                     client_secret='DgQrUlyRndRlDYapNRD6GcOr_D_Vsg',
                     user_agent='smm_project_21',
                     check_for_async=False)

submissions = reddit.subreddit('opensource').hot(limit=5)
[str(x) for x in submissions]
# Out:
# ['qbzsln', 'qcdutu', 'qc2ctx', 'qcadgw', 'qbs9br']

# %%
submission = reddit.submission(id='qbzsln')

# %%
submission.title
# Out:
# 'ReactOS has won the donation competition dedicated to the 30th anniversary of Linux'

# %%
df = pd.DataFrame(df)

# %%
df.head()
# Out:
#        id  result
# 0  18ypya       1
# 1  8u3p2f       1
# 2  194wmf       1
# 3  1h8ctp       1
# 4  17pkxd       1

# %%
df = pd.DataFrame(df)

# %%
len(df)
# Out:
# 610

# %%
from functools import reduce

def factors(n):    
    return set(reduce(list.__add__, 
                ([i, n//i] for i in range(1, int(n**0.5) + 1) if n % i == 0)))

# %%
factors(len(df))
# Out:
# {1, 2, 5, 10, 19, 38, 61, 95, 122, 190, 305, 610, 1159, 2318, 5795, 11590}

# %%
dfList = []
for i in range(0, df.shape[0], 122):
    dfList.append(df[i:i+122])

# %%
len(dfList)
# Out:
# 95

# %%
i=0
for df in dfList:
  df['title'] = df['id'].apply(lambda x: reddit.submission(id = x).title)
  print(f'df {i} is complete')
  i+=1
# Out:
# df 0 is complete
# df 1 is complete
# ---------------------------------------------------------------------------
# Forbidden                                 Traceback (most recent call last)
# <ipython-input-85-7352113e2f9c> in <module>()
#       1 i=0
#       2 for df in dfList:
# ----> 3   df['title'] = df['id'].apply(lambda x: reddit.submission(id = x).title)
#       4   print(f'df {i} is complete')
#       5   i+=1
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/series.py in apply(self, func, convert_dtype, args, **kwds)
#    4211             else:
#    4212                 values = self.astype(object)._values
# -> 4213                 mapped = lib.map_infer(values, f, convert=convert_dtype)
#    4214
#    4215         if len(mapped) and isinstance(mapped[0], Series):
#
# pandas/_libs/lib.pyx in pandas._libs.lib.map_infer()
#
# <ipython-input-85-7352113e2f9c> in <lambda>(x)
#       1 i=0
#       2 for df in dfList:
# ----> 3   df['title'] = df['id'].apply(lambda x: reddit.submission(id = x).title)
#       4   print(f'df {i} is complete')
#       5   i+=1
#
# /usr/local/lib/python3.7/dist-packages/praw/models/reddit/base.py in __getattr__(self, attribute)
#      32         """Return the value of `attribute`."""
#      33         if not attribute.startswith("_") and not self._fetched:
# ---> 34             self._fetch()
#      35             return getattr(self, attribute)
#      36         raise AttributeError(
#
# /usr/local/lib/python3.7/dist-packages/praw/models/reddit/submission.py in _fetch(self)
#     615
#     616     def _fetch(self):
# --> 617         data = self._fetch_data()
#     618         submission_listing, comment_listing = data
#     619         comment_listing = Listing(self._reddit, _data=comment_listing["data"])
#
# /usr/local/lib/python3.7/dist-packages/praw/models/reddit/submission.py in _fetch_data(self)
#     612         name, fields, params = self._fetch_info()
#     613         path = API_PATH[name].format(**fields)
# --> 614         return self._reddit.request("GET", path, params)
#     615
#     616     def _fetch(self):
#
# /usr/local/lib/python3.7/dist-packages/praw/reddit.py in request(self, method, path, params, data, files, json)
#     861                 params=params,
#     862                 timeout=self.config.timeout,
# --> 863                 json=json,
#     864             )
#     865         except BadRequest as exception:
#
# /usr/local/lib/python3.7/dist-packages/prawcore/sessions.py in request(self, method, path, data, files, json, params, timeout)
#     335             params=params,
#     336             timeout=timeout,
# --> 337             url=url,
#     338         )
#     339
#
# /usr/local/lib/python3.7/dist-packages/prawcore/sessions.py in _request_with_retries(self, data, files, json, method, params, timeout, url, retry_strategy_state)
#     264             )
#     265         elif response.status_code in self.STATUS_EXCEPTIONS:
# --> 266             raise self.STATUS_EXCEPTIONS[response.status_code](response)
#     267         elif response.status_code == codes["no_content"]:
#     268             return
#
# Forbidden: received 403 HTTP response

# %%
dfList[0].head()
